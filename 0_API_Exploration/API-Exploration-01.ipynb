# %%
import json
import requests

# %% [markdown]
# ### Answers

# %%
url="https://api.stackexchange.com/2.3/answers?order=asc&sort=activity&site=stackoverflow"

# %%
response = requests.get(url)

# %%
content = dict(response.json())

# %%
content
# Out:
# {'items': [{'owner': {'account_id': 13,
#     'reputation': 2404,
#     'user_id': 19,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/1UwNK.jpg?s=256&g=1',
#     'display_name': 'Mads Kristiansen',
#     'link': 'https://stackoverflow.com/users/19/mads-kristiansen'},
#    'is_accepted': False,
#    'score': 190,
#    'last_activity_date': 1217593157,
#    'creation_date': 1217593157,
#    'answer_id': 29,
#    'question_id': 13,
#    'content_license': 'CC BY-SA 2.5'},
#   {'owner': {'account_id': 9,
#     'reputation': 214528,
#     'user_id': 13,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/1XtZi.jpg?s=256&g=1',
#     'display_name': 'C. K. Young',
#     'link': 'https://stackoverflow.com/users/13/c-k-young'},
#    'is_accepted': False,
#    'score': 44,
#    'last_activity_date': 1217593360,
#    'creation_date': 1217593360,
#    'answer_id': 30,
#    'question_id': 25,
# ...

# %% [markdown]
# ### Questions
